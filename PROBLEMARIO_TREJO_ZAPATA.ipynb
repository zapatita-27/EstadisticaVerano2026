# %% [markdown]
# <a href="https://colab.research.google.com/github/zapatita-27/EstadisticaVerano2026/blob/main/PROBLEMARIO_TREJO_ZAPATA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Unidad 1. Regresión lineal simple y correlación

# %% [markdown]
# ## Medidas de dispersión
# Suma de los cuadrados de las desviaciones de los valores de $X$ con respecto a su media:
# $$ S_{xx} = \sum_{i=1}^{n} (X_i - \bar{X})^2 $$
# Suma de los productos de las desviaciones de los valores de $X$ y $Y$ con respecto a sus medias:
# $$S_{xy} = \sum_{i=1}^{n} (X_i - \bar{X})(Y_i - \bar{Y})$$
# Suma de los cuadrados de las desviaciones de los valores de $Y$ con respecto a su media:
# $$ S_{yy} = \sum_{i=1}^{n} (Y_i - \bar{Y})^2 $$

# %% [markdown]
# ## Coeficiente de correlación y de determinación
# Coeficiente de correlación de Pearson:
# $$ r = \frac{S_{xy}}{\sqrt{S_{xx} \cdot S_{yy}}} $$
# Coeficiente de determinación:
# $$ r^2 $$

# %% [markdown]
# ## Recta de regresión ajustada
# La regresión lineal ajustada se representa mediante estadísticos:
# $$ \hat{Y} = b_0 + b_1 X $$
# donde $\hat{Y}$ representa el valor de $Y$ obtenido mediante la recta de regresión ajustada (no la verdadera $Y$). Los estadísticos $b_0$ y $b_1$ se calculan de la siguiente manera:
#
# $$b_1 = \frac{S_{xy}}{S_{xx}}$$
#
# $$ b_0 = \bar{Y} - b_1 \bar{X} $$

# %% [markdown]
# ## Cálculo de residuales
# Residuales:
# $$e_i = Y_i - \hat{Y}_i$$

# %% [markdown]
# ## Sumas de cuadrados SS (Sum of Squares)
# Suma de los Cuadrados de los Errores:
# $$ SSE = \sum_{i=1}^{n} (Y_i - \hat{Y}_i)^2 = \sum_{i=1}^n e_i^2$$
# Suma total de cuadrados:
# $$SST = \sum_{i=1}^{n} (Y_i - \bar{Y})^2$$
# Suma de cuadrados de regresión:
# $$SSR = \sum_{i=1}^{n} (\hat{Y_i} - \bar{Y})^2$$
# - SST: Mide la variabilidad total de los datos observados.
# - SSR: Mide la variabilidad de los datos que el modelo de regresión explica.
# - SSE: Mide la variabilidad no explicada por el modelo (es decir, los residuos).

# %% [markdown]
# ## Intervalo de confianza
# Estadístico de prueba _t_:
# $$t = \frac{b_1}{SE(b_1)}$$
# Error estándar de $b_1$:
# $$SE(b_1) = \frac{\sqrt{SSE / (n-2)}}   {\sqrt{S_{xx}} }$$
# o
# $$SE(b_1) = \frac{\sqrt{\sum_{i=1}^{n} (Y_i - \hat{Y}_i)^2  / (n-2)}}   {\sqrt{S_{xx}} }$$
#
# Intervalo de confianza para $b_1$:
# $$b_1 - t_{\alpha/2} \cdot SE(b_1) \lt \beta_1 \lt b_1 + t_{\alpha/2} \cdot SE(b_1)$$
# donde $n$ representa la cantidad de pares de datos.

# %% [markdown]
# ## Comprobación de supuestos
# Comprobar suposiciones:
# - Test de shapiro a los residuales $e_i$: Para comprobar si la distribución es normal sobre la recta.
# - Grafico $X$ vs $Y$: Para observar si los datos soportan la suposición de linealidad.
# - Gráfico de residuales: Para observar si los datos soportan la suposición de linealidad, complementario al coeficiente de correlación
# - Test de Breusch-Pagan: Para detectar heteroscedasticidad en regresion lineal

# %% [markdown]
# Test de Shapiro:<br>
# `from scipy.stats import shapiro`<br>
# Después, se obtiene el valor-p:<br>
# `_, valor_p_sh = shapiro(data)`<br>
# - $H_0$: Los datos siguen una distribución normal
# - $H_1$: Los datos no siguen una distribución normal

# %% [markdown]
# Test de Breusch-Pagan:<br>
# `from statsmodels.stats.api import het_breuschpagan`<br>
# Después, se obtiene el valor-p:<br>
# `_, valor_p_bp, _, _ = het_breuschpagan(residuales, X)`
# - $H_0$: Hay homoscedasticidad
# - $H_1$: Hay heteroscedasticidad

# %% [markdown]
# ## ANOVA en regresión lineal
#
# | Fuente de variación | Suma de cuadrados (SS) | Grados de libertad (df) | Promedio de los cuadrados (MS) | Estadístico F |
# |---------------------|------------------------|--------------------------|--------------------------------|---------------|
# | Regresión  | $ SSR$ | $p$ | $MSR = \frac{SSR}{p}$ | $F = \frac{MSR}{MSE}$|
# | Error | $SSE$| $n - p - 1 $| $MSE = \frac{SSE}{n - p - 1} $|     |
# | Total | $SST $| $n - 1$|             |        |
#
# donde $p$ es el número de parámetros para la recta de regresión ajustada (en la regresión simple $p=1$). Las hipótesis son:
# $$H_0: \beta_1 = 0$$
# $$H_1: \beta_1 \ne 0 $$

# %% [markdown]
# ## Problemario de la Unidad 1

# %% [markdown]
# ### Problema 1
# Un profesor intenta mostrar a sus estudiantes la importancia de los exámenes cortos, aun cuando el 90% de la calificación final esté determinada por los exámenes parciales. Él cree que cuanto más altas sean las calificaciones de los exámenes cortos, más alta será la calificación final. Seleccionó una muestra aleatoria de 15 estudiantes de su clase con los siguientes datos:
#
# | Promedio de exámenes cortos | Promedio final |
# |--------------|--------------|
# | 59 | 64 |
# | 92 | 84 |
# | 72 | 77 |
# | 90 | 80 |
# | 95 | 77 |
# | 87 | 81 |
# | 89 | 80 |
# | 77 | 84 |
# | 76 | 80 |
# | 65 | 69 |
# | 97 | 83 |
# | 42 | 40 |
# | 94 | 78 |
# | 62 | 65 |
# | 91 | 90 |
#
#
#
# 1.   Establesca una variable dependiente ($Y$) y una variable independiente ($X$).
# 2.   Realice un diagrama de dispersión para estos datos.
# 3. ¿Los datos soportan la suposición de linealidad?
# 4. Calcule el coeficiente de correlación e interprete el resultado.
# 5. Calcule el coeficiente de determinación e interprete el resultado.
# 6. Obtenga la recta de regresión ajustada y grafíquelo sobre el gráfico de dispersión.
# 7. Obtenga un intervalo de confianza del 95% para la pendiente de la recta de regresión ajustada ($b_1$)
# 8. Calcule los residuales y trace un nuevo gráfico de dispersión. Comente, ¿Parece que se verifican los supuestos?
# 9. Realice la prueba de Shapiro para los residuales y comente el resultado.
# 10. Realice la prueba de Brausch-Pagan para los residuales y comente el resultado.
# 11. Tres estudiantes sacaron 70, 75 y 84 de calificación. Según la recta de regresión ajustada, ¿cuáles son los resultados esperados para estos tres alumnos?
# 12. Realice una tabla ANOVA e interprete el resultado.

# %%
import pandas as pd

df = pd.DataFrame({
    "promedio_examen_cortos": [59, 92, 72, 90, 95, 87, 89, 77, 76, 65, 97, 42, 94, 62, 91],
    "promedio_final": [64, 84, 77, 80, 77, 81, 80, 84, 80, 69, 83, 40, 78, 65, 90]
})

df
# Out:
#     promedio_examen_cortos  promedio_final
# 0                       59              64
# 1                       92              84
# 2                       72              77
# 3                       90              80
# 4                       95              77
# 5                       87              81
# 6                       89              80
# 7                       77              84
# 8                       76              80
# 9                       65              69
# 10                      97              83
# 11                      42              40
# 12                      94              78
# 13                      62              65
# 14                      91              90

# %% [markdown]
# 1. Establesca una variable dependiente ( Y ) y una variable independiente ( X ).

# %%
# Que informacion tengo (x) Variable independiente
# Que informacion tengo (y) Variable dependiente

Y = df["promedio_final"]
X = df["promedio_examen_cortos"]

# %% [markdown]
# 2. Realice un diagrama de dispersión para estos datos.

# %%
# Importamos la librería matplotlib.pyplot y le damos el pseudónimo plt
import matplotlib.pyplot as plt

# Configuración general del gráfico
plt.figure(
    figsize=(6, 4),   # tamaño de la figura (ancho, alto) en pulgadas
    dpi=120           # resolución del gráfico
)

# Gráfico de dispersión
plt.scatter(
    X, Y,
    marker="o",       # forma: googlear "matplotlib.markers"
    color='yellow',     # color de los puntos
    edgecolor='blue',    # borde de los puntos
    alpha=0.8,            # transparencia: 0 es invisible y 1 es color sólido
    s=50,                 # tamaño de los puntos
)

# Etiquetas de los ejes
# eje x
plt.xlabel(
    'Temperatura (°C)', # etiqueta del eje x
    fontsize=12  # tamaño de fuente
)

plt.ylabel(
    'Consumo (kWh)', # etiqueta del eje y
    fontsize=12 # tamaño de fuente
)

# Fuente de los ticks
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

# Márgenes
plt.gca().spines['right'].set_visible(False) # derecha
plt.gca().spines['top'].set_visible(False)   # superior

# Cuadrícula (opcional, pero didáctica)
plt.grid(
    visible=True,
    linestyle='--',
    linewidth=0.7,
    alpha=0.5,
    color="gray"
)

# %% [markdown]
# 3. ¿Los datos soportan la suposición de linealidad?

# %% [markdown]
# No, porque existie una tendencia positivay sigue una relacion de los puntos

# %% [markdown]
# 4. Calcule el coeficiente de correlación e interprete el resultado.

# %%
# Importar la función pearsonr desde scipy.stats
from scipy.stats import pearsonr

# Test de Pearson
# H0: rho = 0     (No hay correlación)
# H1: rho ≠ 0     (Sí hay correlación)
# alpha = 0.05

r, valor_p = pearsonr(X, Y)

print(f"Coeficiente de correlación: {r: 0.4f}")
print(f'valor_p: {valor_p: 0.4f}')
# Out:
# Coeficiente de correlación:  0.8646
# valor_p:  0.0000

# %% [markdown]
# El coeficiente de correlacion es $r=0.8646$, este valor indica que la correlacion es fuerte, dado que esta muy cerca de 1.

# %% [markdown]
# 5. Calcule el coeficiente de determinación e interprete el resultado.

# %%
import statsmodels.api as sm
x_constante = sm.add_constant(X)
modelo = sm.OLS(Y, x_constante).fit()
y_calculada = modelo.predict(x_constante)

# %%
# Coeficiente de determinacion
from sklearn.metrics import r2_score

r2 = r2_score(Y, y_calculada)
print(f"Coeficiente de determinacion: {r2: 0.2%}")
# Out:
# Coeficiente de determinacion:  74.75%

# %% [markdown]
# Con coeficiente de determinacion de $r^2=0.7475$ indica que con los promedios de los examenes cortos, estoy justificando en un 74.75% la variabilidad de los promedios finales. Por lo que el modelo puede tener una buena capacidad de prediccion.

# %% [markdown]
# 6. Obtenga la recta de regresión ajustada y grafíquelo sobre el gráfico de dispersión.

# %%
import statsmodels.api as sm

x_constante = sm.add_constant(X)
modelo = sm.OLS(Y, x_constante).fit()
y_calculada = modelo.predict(x_constante)

modelo.params
# Out:
# const                     24.526822
# promedio_examen_cortos     0.643180
# dtype: float64

# %% [markdown]
# El modelo es:
#
# $$
# \hat{y}=24.526822+0.643180x
# $$
#
# donde $x$ es el promedio en examnes cortos.

# %%
# Importamos la librería matplotlib.pyplot y le damos el pseudónimo plt
import matplotlib.pyplot as plt

# Configuración general del gráfico
plt.figure(
    figsize=(6, 4),   # tamaño de la figura (ancho, alto) en pulgadas
    dpi=120           # resolución del gráfico
)

# Gráfico de dispersión
plt.scatter(
    X, Y,
    marker="o",       # forma: googlear "matplotlib.markers"
    color='yellow',     # color de los puntos
    edgecolor='blue',    # borde de los puntos
    alpha=0.8,            # transparencia: 0 es invisible y 1 es color sólido
    s=50,                 # tamaño de los puntos
)

# Gráfico de línea
plt.plot(
    X, y_calculada,
    color='black',   # color de la línea
    linewidth=1.0,        # grosor de la línea
    linestyle='--',        # estilo de línea
    label='Recta de regresión'
)

# Etiquetas de los ejes
# eje x
plt.xlabel(
    'Temperatura (°C)', # etiqueta del eje x
    fontsize=12  # tamaño de fuente
)

plt.ylabel(
    'Consumo (kWh)', # etiqueta del eje y
    fontsize=12 # tamaño de fuente
)

# Fuente de los ticks
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

# Márgenes
plt.gca().spines['right'].set_visible(False) # derecha
plt.gca().spines['top'].set_visible(False)   # superior

# Cuadrícula (opcional, pero didáctica)
plt.grid(
    visible=True,
    linestyle='--',
    linewidth=0.7,
    alpha=0.5,
    color="gray"
)

# %% [markdown]
# 7. Obtenga un intervalo de confianza del 95% para la pendiente de la recta de regresión ajustada ( b1 )

# %% [markdown]
# La ecuacion de la recta es:
#
# $$
# \hat{y}=by+b1X
# $$

# %%
#intervalos de confianza
modelo.conf_int(alpha=0.05)
# Out:
#                                0          1
# const                   6.441997  42.611646
# promedio_examen_cortos  0.419219   0.867141

# %% [markdown]
# El verdadero $b_0$ está entre $6.441997$ y $42.611646$ con una confianza del 95%. Esto indica que las calificaciones ($X=0$) tienen una categoria de promedios de examenes finales.
# ($Y$) que está entre estos dos valores.
# EL verdadero valor de $b 1$ está entre $ 0.419219% y $-0.
# 0.867141$ con un 95% de confianza. Dado que dentre de este intervalo no está el valor de cero, entonces la relación es significativa. También indica que por cada falta se pierde entre 0.867141 y 0.867141 en la categoría de salario

# %% [markdown]
# 8. Calcule los residuales y trace un nuevo gráfico de dispersión. Comente, ¿Parece que se verifican los supuestos?

# %%
residuales = modelo.resid

# %%
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm # Importamos statsmodels

import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm # Importamos statsmodels

# Redefinimos df para asegurar su disponibilidad
df = pd.DataFrame({
    "promedio_examen_cortos": [59, 92, 72, 90, 95, 87, 89, 77, 76, 65, 97, 42, 94, 62, 91],
    "promedio_final": [64, 84, 77, 80, 77, 81, 80, 84, 80, 69, 83, 40, 78, 65, 90]
})

# Redefinimos Y y X
Y = df["promedio_final"]
X = df["promedio_examen_cortos"]

# Recalculamos y_calculada
x_constante = sm.add_constant(X)
modelo = sm.OLS(Y, x_constante).fit()
y_calculada = modelo.predict(x_constante)

# Calculamos los residuales
residuales = Y - y_calculada

# Configuración general del gráfico
plt.figure(
    figsize=(6, 4),   # tamaño de la figura (ancho, alto) en pulgadas
    dpi=120           # resolución del gráfico
)

# Gráfico de dispersión
plt.scatter(
    X, residuales,
    marker="o",       # forma: googlear "matplotlib.markers"
    color='yellow',     # color de los puntos
    edgecolor='blue',    # borde de los puntos
    alpha=0.8,            # transparencia: 0 es invisible y 1 es color sólido
    s=50,                 # tamaño de los puntos
)

# Gráfico de línea
plt.plot(
    X, y_calculada * 0,
    color='black',   # color de la linea
    linewidth=1.0,        # grosor de la linea
    linestyle='--',        # estilo de linea
    label='Recta de regresión'
)

# Etiquetas de los ejes
# eje x
plt.xlabel(
    'Promedio examenes cortos', # etiqueta del eje x
    fontsize=12  # tamaño de fuente
)

plt.ylabel(
    'Residuales', # etiqueta del eje y
    fontsize=12 # tamaño de fuente
)

# Fuente de los ticks
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

# Márgenes
plt.gca().spines['right'].set_visible(False) # derecha
plt.gca().spines['top'].set_visible(False)   # superior

# Cuadrícula (opcional, pero didáctica)
plt.grid(
    visible=True,
    linestyle='--',
    linewidth=0.7,
    alpha=0.5,
    color="gray"
)

# %% [markdown]
# Par los supuestos:
#
# * Linealidad: Parece que sí, por que los residuos se distribuyen aleatoriamente alrededor de la linea de cero sin mostrar patrones curvos ni tendencias claras.
# * Normalidad: Sí cumple con la normalidad, porque los residuos se reparten de forma simetrica respecto al cero.
# * Homoscedasticidad: No cumple con la homoscedasticidad,porque la dispersion aumenta conforme crece el promedio.
# * Independencia: Sí cılmple, porque son cada observacion corresponde a un estudiante distinto.

# %% [markdown]
# 9. Realice la prueba de Shapiro para los residuales y comente el resultado.

# %%
from scipy.stats import shapiro
import matplotlib.pyplot as plt
import seaborn as sns

#test de shapiro-Wilk
#Ho:Hay normalidad
#Hi:No hay normalidad

# Prueba de Shapiro-Wilk
stat, valor_p_sh = shapiro(residuales)
print(f"valor-p (Shapiro) = {valor_p_sh}")

# Visualización: Q-Q plot
sm.qqplot(residuales, line='s')
plt.title("Q-Q plot de residuos")
plt.show()

# Histograma
sns.histplot(residuales, kde=True)
plt.title("Histograma de residuos")
plt.show()
# Out:
# valor-p (Shapiro) = 0.901827735700704

# %% [markdown]
# 10. Realice la prueba de Brausch-Pagan para los residuales y comente el resultado.

# %%
# Test de Breusch-Pagan
# H0: No hay heterocedasticidad (dispersión es igual en toda la recta)
# H1: Hay Heterocedasticidad (dispersión distinta a lo largo de la recta)
# alpha = 0.05

from statsmodels.stats.api import het_breuschpagan
import statsmodels.api as sm
x_constante = sm.add_constant(X)
_, valor_p_bp, _, _ = het_breuschpagan(residuales, x_constante)
print(f'valor-p de Breusch-Pagan: {valor_p_bp: 0.4f}\n')
# Out:
# valor-p de Breusch-Pagan:  0.2289

# %% [markdown]
# 11. Utiliza la recta de regresión para interpolar dos valores y extrapolar uno. Comenta estos resultados.

# %%
# minimo ausencias: 11
# maximo ausencias: 40

# interpolar, valores de x entre 11 y 40

# interpolar 1
y_25 = modelo.predict([1, 25])
y_32 = modelo.predict ([1,32])

print(f"Para x = 25, y = {y_25[0]: 0.4f}")
print(f"Para x = 32, y = {y_32[0]: 0.4f}")
# Out:
# Para x = 25, y =  40.6063
# Para x = 32, y =  45.1086

# %%
df["salario_predicho"] = y_calculada.round()
df
# Out:
#     promedio_examen_cortos  promedio_final  salario_predicho
# 0                       59              64              62.0
# 1                       92              84              84.0
# 2                       72              77              71.0
# 3                       90              80              82.0
# 4                       95              77              86.0
# 5                       87              81              80.0
# 6                       89              80              82.0
# 7                       77              84              74.0
# 8                       76              80              73.0
# 9                       65              69              66.0
# 10                      97              83              87.0
# 11                      42              40              52.0
# 12                      94              78              85.0
# 13                      62              65              64.0
# 14                      91              90              83.0

# %% [markdown]
# 12. Realice una tabla ANOVA e interprete el resultado.

# %%
# test de ANOVA (Analysis of Variance)
# H0: beta_1 = 0   (No hay correlación)
# H1: beta_1 ≠ 0   (Sí hay correlación)

import statsmodels.api as sm
from statsmodels.formula.api import ols
# Y ~ X
modelo_lineal = ols(
    '''promedio_final ~ promedio_examen_cortos''',
    data = df).fit()
tabla_anova = sm.stats.anova_lm(modelo_lineal)
tabla_anova
# Out:
#                           df       sum_sq      mean_sq          F    PR(>F)
# promedio_examen_cortos   1.0  1538.228959  1538.228959  38.492412  0.000032
# Residual                13.0   519.504375    39.961875        NaN       NaN

# %% [markdown]
# Sí hay correlación porque el valor-p de $0.000032$ es menor que el nivel de significancia establecido $\alpha=0.05$.
# I
# En los residuales del anova se puede ver la variabilidad explicada porla recta de regresión es mucho mayor que la variabilidad que queda sin explicar.

# %% [markdown]
# ### Problema 2
# William Hawkins, vicepresidente de personal de la International Motors, trabaja en la relación entre el salario de un trabajador y el porcentaje de ausentismo. Hawkins dividió el intervalo de salarios de International en 12 grados o niveles (1 es el menor grado, 12 el más alto) y después muestreó aleatoriamente a un grupo de trabajadores. Determinó el grado de salario de cada trabajador y el número de días que ese empleado había faltado en los últimos 3 años.
#
# | Categoría de salario | 11 | 10 | 8  | 5  | 9  | 7  | 3  |
# |----------------------|----|----|----|----|----|----|----|
# | Ausencias           | 18 | 17 | 29 | 36 | 11 | 28 | 35 |
#
# | Categoría de salario | 11 | 8  | 7  | 2  | 9  | 8  | 3  |
# |----------------------|----|----|----|----|----|----|----|
# | Ausencias           | 14 | 20 | 32 | 39 | 16 | 31 | 40 |
#
# 1.   Establesca una variable dependiente ($Y$) y una variable independiente ($X$).
# 2.   Realice un diagrama de dispersión para estos datos.
# 3. ¿Los datos soportan la suposición de linealidad?
# 4. Calcule el coeficiente de correlación e interprete el resultado.
# 5. Calcule el coeficiente de determinación e interprete el resultado.
# 6. Obtenga la recta de regresión ajustada y grafíquelo sobre el gráfico de dispersión.
# 7. Obtenga un intervalo de confianza del 95% para la pendiente de la recta de regresión ajustada ($b_1$)
# 8. Calcule los residuales y trace un nuevo gráfico de dispersión. Comente, ¿Parece que se verifican los supuestos?
# 9. Realice la prueba de Shapiro para los residuales y comente el resultado.
# 10. Realice la prueba de Brausch-Pagan para los residuales y comente el resultado.
# 11. Utiliza la recta de regresión para interpolar dos valores y extrapolar uno. Comenta estos resultados.
# 12. Realice una tabla ANOVA e interprete el resultado.

# %%
import pandas as pd

df = pd.DataFrame({
    "salario": [11,10,8,5,9,7,3,11,8,7,2,9,8,3],
    "ausencias": [18,17,29,36,11,28,35,14,20,32,39,16,31,40]
})

df
# Out:
#     salario  ausencias
# 0        11         18
# 1        10         17
# 2         8         29
# 3         5         36
# 4         9         11
# 5         7         28
# 6         3         35
# 7        11         14
# 8         8         20
# 9         7         32
# 10        2         39
# 11        9         16
# 12        8         31
# 13        3         40

# %% [markdown]
# 1. Establesca una variable dependiente ( Y ) y una variable independiente ( X ).
# + $Y$: es el salario porque es dependiente
# + $X$: son las ausencias porque es independiente

# %%
# Y: salarios
# X: ausencias

X = df["ausencias"]
Y = df["salario"]

# %% [markdown]
# 2. Realice un diagrama de dispersión para estos datos.

# %%
# Importamos la librería matplotlib.pyplot y le damos el pseudónimo plt
import matplotlib.pyplot as plt

# Configuración general del gráfico
plt.figure(
    figsize=(6, 4),   # tamaño de la figura (ancho, alto) en pulgadas
    dpi=120           # resolución del gráfico
)

# Gráfico de dispersión
plt.scatter(
    X, Y,
    marker="o",       # forma: googlear "matplotlib.markers"
    color='yellow',     # color de los puntos
    edgecolor='blue',    # borde de los puntos
    alpha=0.8,            # transparencia: 0 es invisible y 1 es color sólido
    s=50,                 # tamaño de los puntos
)

# Etiquetas de los ejes
# eje x
plt.xlabel(
    'ausencias (°C)', # etiqueta del eje x
    fontsize=12  # tamaño de fuente
)

plt.ylabel(
    'Consumo (kWh)', # etiqueta del eje y
    fontsize=12 # tamaño de fuente
)

# Fuente de los ticks
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

# Márgenes
plt.gca().spines['right'].set_visible(False) # derecha
plt.gca().spines['top'].set_visible(False)   # superior

# Cuadrícula (opcional, pero didáctica)
plt.grid(
    visible=True,
    linestyle='--',
    linewidth=0.7,
    alpha=0.5,
    color="gray"
)

# %% [markdown]
# 3. ¿Los datos soportan la suposición de linealidad?
#
# Si, por que los datos soportan la suposicion de linealidad.

# %% [markdown]
# 4. Calcule el coeficiente de correlación e interprete el resultado.

# %%
# Importar la función pearsonr desde scipy.stats
from scipy.stats import pearsonr

# Test de Pearson
# H0: rho = 0     (No hay correlación)
# H1: rho ≠ 0     (Sí hay correlación)
# alpha = 0.05

r, valor_p = pearsonr(X, Y)

print(f"Coeficiente de correlación: {r: 0.4f}")
print(f'valor_p: {valor_p: 0.4f}')
# Out:
# Coeficiente de correlación: -0.8801
# valor_p:  0.0000

# %% [markdown]
# El coeficiente de correlacion es $r=-0.8801$, este valor indica que la correlacion es fuerte, dado que esta muy cerca de 1. Ademas, el que se negativa, implica que aumentar las ausencias ($X$) disminuye el salario ($Y$).

# %% [markdown]
# 5. Calcule el coeficiente de determinación e interprete el resultado.

# %%
import statsmodels.api as sm
x_constante = sm.add_constant(X)
modelo = sm.OLS(Y, x_constante).fit()
y_calculada = modelo.predict(x_constante)

# %%
# Coeficiente de determinacion
from sklearn.metrics import r2_score

r2 = r2_score(Y, y_calculada)
print(f"Coeficiente de determinacion: {r2: 0.2%}")
# Out:
# Coeficiente de determinacion:  77.46%

# %% [markdown]
# Con coeficiente de determinacion de $r^2=0.7746$ indica que con las ausencias estoy justificando en un 77.46% la variabilidad de los salarios. Por lo que el modelo puede tener una buena capacidad de prediccion.

# %% [markdown]
# 6. Obtenga la recta de regresión ajustada y grafíquelo sobre el gráfico de dispersión:

# %%
import statsmodels.api as sm

x_constante = sm.add_constant(X)
modelo = sm.OLS(Y, x_constante).fit()
y_calculada = modelo.predict(x_constante)

modelo.params
# Out:
# const        14.058843
# ausencias    -0.261814
# dtype: float64

# %% [markdown]
# La ecuacion de la recta es:
#
# $$
# \hat{y}=14.058843-0.261814X
# $$

# %%
# Importamos la librería matplotlib.pyplot y le damos el pseudónimo plt
import matplotlib.pyplot as plt

# Configuración general del gráfico
plt.figure(
    figsize=(6, 4),   # tamaño de la figura (ancho, alto) en pulgadas
    dpi=120           # resolución del gráfico
)

# Gráfico de dispersión
plt.scatter(
    X, Y,
    marker="o",       # forma: googlear "matplotlib.markers"
    color='yellow',     # color de los puntos
    edgecolor='blue',    # borde de los puntos
    alpha=0.8,            # transparencia: 0 es invisible y 1 es color sólido
    s=50,                 # tamaño de los puntos
)

# Gráfico de línea
plt.plot(
    X, y_calculada,
    color='black',   # color de la línea
    linewidth=1.0,        # grosor de la línea
    linestyle='--',        # estilo de línea
    label='Recta de regresión'
)

# Etiquetas de los ejes
# eje x
plt.xlabel(
    'ausencias (°C)', # etiqueta del eje x
    fontsize=12  # tamaño de fuente
)

plt.ylabel(
    'Consumo (kWh)', # etiqueta del eje y
    fontsize=12 # tamaño de fuente
)

# Fuente de los ticks
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

# Márgenes
plt.gca().spines['right'].set_visible(False) # derecha
plt.gca().spines['top'].set_visible(False)   # superior

# Cuadrícula (opcional, pero didáctica)
plt.grid(
    visible=True,
    linestyle='--',
    linewidth=0.7,
    alpha=0.5,
    color="gray"
)

# %% [markdown]
# 7. Obtenga un intervalo de confianza del 95% para la pendiente de la recta de regresión ajustada ( b1 )

# %% [markdown]
# La ecuacion de la recta es:
#
# $$
# \hat{y}=by+b1X
# $$

# %%
#intervalos de confianza
modelo.conf_int(alpha=0.05)
# Out:
#                    0          1
# const      11.587445  16.530241
# ausencias  -0.350638  -0.172989

# %% [markdown]
# El verdadero $b_0$ está entre $11.587445$ y $16.530241$ con una confianza del 95%. Esto indica que una persona sin ausencias ($X=0$) tiene una categoría de salario
# ($Y$) que está entre estos dos valores.
# EL verdadero valor de $b 1$ está entre $ 0.350635% y $-0.
# 172989$ con un 95% de confianza. Dado que dentre de este intervalo no está el valor de cero, entonces la relación es significativa. También indica que por cada falta se pierde entre 0.172989 y 0.350638 en la categoría de salario

# %% [markdown]
# 8. Calcule los residuales y trace un nuevo gráfico de dispersión. Comente, ¿Parece que se verifican los supuestos?

# %%
residuales = modelo.resid

# %%
# Importamos la librería matplotlib.pyplot y le damos el pseudónimo plt
import matplotlib.pyplot as plt

residuales = modelo.resid

# Configuración general del gráfico
plt.figure(
    figsize=(6, 4),   # tamaño de la figura (ancho, alto) en pulgadas
    dpi=120           # resolución del gráfico
)


# Gráfico de dispersión
plt.scatter(
    X, residuales,
    marker="o",       # forma: googlear "matplotlib.markers"
    color='blue',     # color de los puntos
    edgecolor='black',    # borde de los puntos
    alpha=0.8,            # transparencia: 0 es invisible y 1 es color sólido
    s=50,                 # tamaño de los puntos
)

 #Gráfico de línea
plt.plot(
    X,y_calculada * 0,
    color='black',   # color de la línea
    linewidth=1.0,        # grosor de la línea
    linestyle='--',        # estilo de línea
    label='Recta de regresión'
)

# Etiquetas de los ejes
# eje x
plt.xlabel(
    'Ausencias', # etiqueta del eje x
    fontsize=12  # tamaño de fuente
)

plt.ylabel(
    'Salario', # etiqueta del eje y
    fontsize=12 # tamaño de fuente
)

# Fuente de los ticks
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

# Márgenes
plt.gca().spines['right'].set_visible(False) # derecha
plt.gca().spines['top'].set_visible(False)   # superior

# Cuadrícula (opcional, pero didáctica)
plt.grid(
    visible=True,
    linestyle='--',
    linewidth=0.7,
    alpha=0.5,
    color="gray"
)

# %% [markdown]
# Par los supuestos:
#
# * Linealidad: Parece que sí, porque los puntos se distribuyen al rededor de una linea recta con una tendencia decreciente clara.
# * Normalidad: Sí cumple con la normalidad, porque los residuos se dispersan de forma simetrica al rededor de la recta ajustada.
# * Homoscedasticidad: Sí cumple con la homoscedasticidad, porque la dispersion vertical de llos puntos se mantiene aproximadamente constante a lo largo de todo el rango de la variable independiente.
# * Independencia: Sí cılmple, porque son diferentes personas.

# %% [markdown]
# 9. Realice la prueba de Shapiro para los residuales y comente el resultado.

# %%
from scipy.stats import shapiro
import matplotlib.pyplot as plt
import seaborn as sns

# n < 30, Shapiro-Wilk es el mas confiable
# n >= 30, Histograma o Q-Q plot

#test de shapiro-Wilk
# 1
#Ho:Hay normalidad   0.4172971767713699
# 0.05 (Assuming this was intended as alpha value or a note)
#Hi:No hay normalidad
# 0

# Prueba de Shapiro-Wilk
stat, valor_p_sh = shapiro(residuales)
print(f"valor-p (Shapiro) = {valor_p_sh}")

# Visualización: Q-Q plot
sm.qqplot(residuales, line='s')
plt.title("Q-Q plot de residuos")
plt.show()

# Histograma
sns.histplot(residuales, kde=True)
plt.title("Histograma de residuos")
plt.show()
# Out:
# valor-p (Shapiro) = 0.4172971767713699

# %% [markdown]
# 10. Realice la prueba de Brausch-Pagan para los residuales y comente el resultado.

# %%
# Test de Breusch-Pagan
# H0: No hay heterocedasticidad (dispersión es igual en toda la recta)
# H1: Hay Heterocedasticidad (dispersión distinta a lo largo de la recta)
# alpha = 0.05

from statsmodels.stats.api import het_breuschpagan
import statsmodels.api as sm
x_constante = sm.add_constant(X)
_, valor_p_bp, _, _ = het_breuschpagan(residuales, x_constante)
print(f'valor-p de Breusch-Pagan: {valor_p_bp: 0.4f}\n')
# Out:
# valor-p de Breusch-Pagan:  0.8955

# %% [markdown]
# 11. Utiliza la recta de regresión para interpolar dos valores y extrapolar uno. Comenta estos resultados.

# %%
# minimo ausencias: 11
# maximo ausencias: 40

# interpolar, valores de x entre 11 y 40

# interpolar 1
y_25 = modelo.predict([1, 25])
y_32 = modelo.predict ([1,32])

print(f"Para x = 25, y = {y_25[0]: 0.4f}")
print(f"Para x = 32, y = {y_32[0]: 0.4f}")
# Out:
# Para x = 25, y =  7.5135
# Para x = 32, y =  5.6808

# %%
df["salario_predicho"] = y_calculada.round()
df
# Out:
#     salario  ausencias  salario_predicho
# 0        11         18               9.0
# 1        10         17              10.0
# 2         8         29               6.0
# 3         5         36               5.0
# 4         9         11              11.0
# 5         7         28               7.0
# 6         3         35               5.0
# 7        11         14              10.0
# 8         8         20               9.0
# 9         7         32               6.0
# 10        2         39               4.0
# 11        9         16              10.0
# 12        8         31               6.0
# 13        3         40               4.0

# %% [markdown]
# 12. Realice una tabla ANOVA e interprete el resultado.

# %%
# test de ANOVA (Analysis of Variance)
# H0: beta_1 = 0   (No hay correlación)
# H1: beta_1 ≠ 0   (Sí hay correlación)

import statsmodels.api as sm
from statsmodels.formula.api import ols
# Y ~ X
modelo_lineal = ols(
    '''salario ~ ausencias''',
    data = df).fit()
tabla_anova = sm.stats.anova_lm(modelo_lineal)
tabla_anova
# Out:
#              df     sum_sq    mean_sq          F    PR(>F)
# ausencias   1.0  87.034348  87.034348  41.243954  0.000033
# Residual   12.0  25.322795   2.110233        NaN       NaN

# %% [markdown]
# Sí hay correlación porque el valor-p de $0.000033$ es menor a un nivel de significancia $\alpha=0.05$.
# I
# En los residuales del anova se puede ver la variabilidad explicada porla recta de regresión es mucho mayor que la variabilidad que queda sin explicar

# %% [markdown]
# ### Problema 3
# A menudo, quienes hacen la contabilidad de costos estiman los gastos generales con base en el nivel de producción. En Standard Knitting Co. han reunido información acerca de los gastos generales y las unidades producidas en diferentes plantas.
#
# | Gastos generales | 191 | 170 | 272 | 155 | 280 | 173 | 234 | 116 | 153 | 178 |
# |------------------|-----|-----|-----|-----|-----|-----|-----|-----|-----|-----|
# | Unidades        |  40 |  42 |  53 |  35 |  56 |  39 |  48 |  30 |  37 |  40 |
#
# 1.   Establesca una variable dependiente ($Y$) y una variable independiente ($X$).
# 2.   Realice un diagrama de dispersión para estos datos.
# 3. ¿Los datos soportan la suposición de linealidad?
# 4. Calcule el coeficiente de correlación e interprete el resultado.
# 5. Calcule el coeficiente de determinación e interprete el resultado.
# 6. Obtenga la recta de regresión ajustada y grafíquelo sobre el gráfico de dispersión.
# 7. Obtenga un intervalo de confianza del 95% para la pendiente de la recta de regresión ajustada ($b_1$)
# 8. Calcule los residuales y trace un nuevo gráfico de dispersión. Comente, ¿Parece que se verifican los supuestos?
# 9. Realice la prueba de Shapiro para los residuales y comente el resultado.
# 10. Realice la prueba de Brausch-Pagan para los residuales y comente el resultado.
# 11. Utiliza la recta de regresión para interpolar dos valores y extrapolar uno. Comenta estos resultados.
# 12. Realice una tabla ANOVA e interprete el resultado.

# %%
import pandas as pd

df = pd.DataFrame({
    "Gatos generales": [191,170,272,155,280,173,234,116,153,178],
    "Unidades": [40,42,53,35,56,39,48,30,37,40]

})

df
# Out:
#    Gatos generales  Unidades
# 0              191        40
# 1              170        42
# 2              272        53
# 3              155        35
# 4              280        56
# 5              173        39
# 6              234        48
# 7              116        30
# 8              153        37
# 9              178        40

# %% [markdown]
# 1. Establesca una variable dependiente ( Y ) y una variable independiente ( X ).

# %%
# Que informacion tengo (x) Variable independiente
# Que informacion tengo (y) Variable dependiente

X = df["Unidades"]
Y = df["Gatos generales"]

# %% [markdown]
# 2. Realice un diagrama de dispersión para estos datos.

# %%
# Importamos la librería matplotlib.pyplot y le damos el pseudónimo plt
import matplotlib.pyplot as plt

# Configuración general del gráfico
plt.figure(
    figsize=(6, 4),   # tamaño de la figura (ancho, alto) en pulgadas
    dpi=120           # resolución del gráfico
)

# Gráfico de dispersión
plt.scatter(
    X, Y,
    marker="o",       # forma: googlear "matplotlib.markers"
    color='yellow',     # color de los puntos
    edgecolor='blue',    # borde de los puntos
    alpha=0.8,            # transparencia: 0 es invisible y 1 es color sólido
    s=50,                 # tamaño de los puntos
)

# Etiquetas de los ejes
# eje x
plt.xlabel(
    'ausencias (°C)', # etiqueta del eje x
    fontsize=12  # tamaño de fuente
)

plt.ylabel(
    'Consumo (kWh)', # etiqueta del eje y
    fontsize=12 # tamaño de fuente
)

# Fuente de los ticks
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

# Márgenes
plt.gca().spines['right'].set_visible(False) # derecha
plt.gca().spines['top'].set_visible(False)   # superior

# Cuadrícula (opcional, pero didáctica)
plt.grid(
    visible=True,
    linestyle='--',
    linewidth=0.7,
    alpha=0.5,
    color="gray"
)

# %% [markdown]
# 3. ¿Los datos soportan la suposición de linealidad?

# %% [markdown]
# Sí, el diagrama de dispersión sugiere una relación lineal positiva entre las unidades producidas y los gastos generales, ya que los puntos tienden a seguir una línea recta ascendente.

# %% [markdown]
# 4. Calcule el coeficiente de correlación e interprete el resultado.

# %%
# Importar la función pearsonr desde scipy.stats
from scipy.stats import pearsonr

# Test de Pearson
# H0: rho = 0     (No hay correlación)
# H1: rho ≠ 0     (Sí hay correlación)
# alpha = 0.05

r, valor_p = pearsonr(X, Y)

print(f"Coeficiente de correlación: {r: 0.4f}")
print(f'valor_p: {valor_p: 0.4f}')
# Out:
# Coeficiente de correlación:  0.9835
# valor_p:  0.0000

# %% [markdown]
# El coeficiente de correlacion es $r=0.9835$, este valor indica que la correlacion es fuerte, dado que esta muy cerca de 1. Ademas, el que se negativa, implica que aumentar las ausencias ($X$) disminuye el salario ($Y$).

# %% [markdown]
# 5. Calcule el coeficiente de determinación e interprete el resultado.

# %%
import statsmodels.api as sm
x_constante = sm.add_constant(X)
modelo = sm.OLS(Y, x_constante).fit()
y_calculada = modelo.predict(x_constante)

# Coeficiente de determinacion
from sklearn.metrics import r2_score

r2 = r2_score(Y, y_calculada)
print(f"Coeficiente de determinacion: {r2: 0.2%}")
# Out:
# Coeficiente de determinacion:  96.73%

# %% [markdown]
# Con coeficiente de determinacion de $r^2=0.9673$ indica que con las ausencias estoy justificando en un 96.73% la variabilidad de gastos generales. Por lo que el modelo puede tener una buena capacidad de prediccion.

# %% [markdown]
# 6. Obtenga la recta de regresión ajustada y grafíquelo sobre el gráfico de dispersión.

# %%
import statsmodels.api as sm
import pandas as pd

# Redefine df, X, Y for Problem 3 to ensure context
df = pd.DataFrame({
    "Gatos generales": [191,170,272,155,280,173,234,116,153,178],
    "Unidades": [40,42,53,35,56,39,48,30,37,40]
})

X = df["Unidades"]
Y = df["Gatos generales"]

x_constante = sm.add_constant(X)
modelo = sm.OLS(Y, x_constante).fit()
y_calculada = modelo.predict(x_constante)

modelo.params
# Out:
# const      -80.442857
# Unidades     6.491497
# dtype: float64

# %% [markdown]
# La ecuacion de la recta es:
#
# $$
# \hat{y}=-80.442857+6.491497X
# $$

# %%
# Importamos la librería matplotlib.pyplot y le damos el pseudónimo plt
import matplotlib.pyplot as plt

# Configuración general del gráfico
plt.figure(
    figsize=(6, 4),   # tamaño de la figura (ancho, alto) en pulgadas
    dpi=120           # resolución del gráfico
)

# Gráfico de dispersión
plt.scatter(
    X, Y,
    marker="o",       # forma: googlear "matplotlib.markers"
    color='yellow',     # color de los puntos
    edgecolor='blue',    # borde de los puntos
    alpha=0.8,            # transparencia: 0 es invisible y 1 es color sólido
    s=50,                 # tamaño de los puntos
)

# Gráfico de línea
plt.plot(
    X, y_calculada,
    color='black',   # color de la línea
    linewidth=1.0,        # grosor de la línea
    linestyle='--',        # estilo de línea
    label='Recta de regresión'
)

# Etiquetas de los ejes
# eje x
plt.xlabel(
    'ausencias (°C)', # etiqueta del eje x
    fontsize=12  # tamaño de fuente
)

plt.ylabel(
    'Consumo (kWh)', # etiqueta del eje y
    fontsize=12 # tamaño de fuente
)

# Fuente de los ticks
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

# Márgenes
plt.gca().spines['right'].set_visible(False) # derecha
plt.gca().spines['top'].set_visible(False)   # superior

# Cuadrícula (opcional, pero didáctica)
plt.grid(
    visible=True,
    linestyle='--',
    linewidth=0.7,
    alpha=0.5,
    color="gray"
)

# %% [markdown]
# 7. Obtenga un intervalo de confianza del 95% para la pendiente de la recta de regresión ajustada ( b1 )

# %% [markdown]
# La ecuacion de la recta es:
#
# $$
# \hat{y}=by+b1X
# $$

# %%
#intervalos de confianza
modelo.conf_int(alpha=0.05)
# Out:
#                    0          1
# const    -121.986373 -38.899341
# Unidades    5.518450   7.464543

# %% [markdown]
# El verdadero $b_0$ está entre $-121.986373$ y $-38.899341$ con una confianza del 95%. Esto indica que las unidades ($X=0$) tiene una categoría de datos generales
# ($Y$) que está entre estos dos valores.
# EL verdadero valor de $b 1$ está entre $ 0.350635% y $-0.
# 172989$ con un 95% de confianza. Dado que dentre de este intervalo no está el valor de cero, entonces la relación es significativa. También indica que por cada falta se pierde entre 7.464543y 5.518450 en la categoría de datos generales.

# %% [markdown]
# 8. Calcule los residuales y trace un nuevo gráfico de dispersión. Comente, ¿Parece que se verifican los supuestos?

# %%
# Importamos la librería matplotlib.pyplot y le damos el pseudónimo plt
import matplotlib.pyplot as plt

residuales = modelo.resid

# Configuración general del gráfico
plt.figure(
    figsize=(6, 4),   # tamaño de la figura (ancho, alto) en pulgadas
    dpi=120           # resolución del gráfico
)


# Gráfico de dispersión
plt.scatter(
    X, residuales,
    marker="o",       # forma: googlear "matplotlib.markers"
    color='blue',     # color de los puntos
    edgecolor='black',    # borde de los puntos
    alpha=0.8,            # transparencia: 0 es invisible y 1 es color sólido
    s=50,                 # tamaño de los puntos
)

 #Gráfico de línea
plt.plot(
    X,y_calculada * 0,
    color='black',   # color de la línea
    linewidth=1.0,        # grosor de la línea
    linestyle='--',        # estilo de línea
    label='Recta de regresión'
)

# Etiquetas de los ejes
# eje x
plt.xlabel(
    'Ausencias', # etiqueta del eje x
    fontsize=12  # tamaño de fuente
)

plt.ylabel(
    'Salario', # etiqueta del eje y
    fontsize=12 # tamaño de fuente
)

# Fuente de los ticks
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

# Márgenes
plt.gca().spines['right'].set_visible(False) # derecha
plt.gca().spines['top'].set_visible(False)   # superior

# Cuadrícula (opcional, pero didáctica)
plt.grid(
    visible=True,
    linestyle='--',
    linewidth=0.7,
    alpha=0.5,
    color="gray"
)

# %% [markdown]
# Par los supuestos:
#
# * Linealidad: Parece que sí, porque los puntos se agrupan al rededor de una linea recta con tendencia creciente.
# * Normalidad: Sí cumple con la normalidad, porque la dispersion son simetricos, la mayoria cerca de ellas y pocos alejados.
# * Homoscedasticidad: Sí cumple con la homoscedasticidad, porque la variacion vertical de los puntos se mantiene constante a todo el rango de la variable independiente.
# * Independencia: Sí cılmple, porque cada observacion corresponde a registros independientes entre si.

# %% [markdown]
# 9. Realice la prueba de Shapiro para los residuales y comente el resultado.

# %%
from scipy.stats import shapiro
import matplotlib.pyplot as plt
import seaborn as sns

# Prueba de Shapiro-Wilk
stat, valor_p_sh = shapiro(residuales)
print(f"valor-p (Shapiro) = {valor_p_sh: 0.4f}")

# Visualización: Q-Q plot
sm.qqplot(residuales, line='s')
plt.title("Q-Q plot de residuos")
plt.show()

# Histograma
sns.histplot(residuales, kde=True)
plt.title("Histograma de residuos")
plt.show()
# Out:
# valor-p (Shapiro) =  0.2205

# %% [markdown]
# 10. Realice la prueba de Brausch-Pagan para los residuales y comente el resultado.

# %%
from statsmodels.stats.api import het_breuschpagan
import statsmodels.api as sm

x_constante = sm.add_constant(X)
_, valor_p_bp, _, _ = het_breuschpagan(residuales, x_constante)
print(f'valor-p de Breusch-Pagan: {valor_p_bp: 0.4f}\n')
# Out:
# valor-p de Breusch-Pagan:  0.9858

# %% [markdown]
# 11. Utiliza la recta de regresión para interpolar dos valores y extrapolar uno. Comenta estos resultados.

# %%
import pandas as pd
import statsmodels.api as sm

# Redefine df, X, Y for Problem 3 to ensure context
df = pd.DataFrame({
    "Gatos generales": [191,170,272,155,280,173,234,116,153,178],
    "Unidades": [40,42,53,35,56,39,48,30,37,40]
})

X = df["Unidades"]
Y = df["Gatos generales"]

# Redefine modelo for Problem 3
x_constante = sm.add_constant(X)
modelo = sm.OLS(Y, x_constante).fit()

# Interpolate two values and extrapolate one
# Minimo de Unidades: 30
# Maximo de Unidades: 56
valores_a_predecir_interpolar = [45, 50] # within [30, 56]
valor_a_predecir_extrapolar = 60 # outside [30, 56]

print("Resultados esperados (Predicciones):")

print("Interpolación:")
for val in valores_a_predecir_interpolar:
  pred = modelo.predict([1, val])[0]
  print(f"   Para X (Unidades) = {val} -> Y (Gastos generales) estimado = {pred:.2f}")

print("\nExtrapolación:")
pred_ext = modelo.predict([1, valor_a_predecir_extrapolar])[0]
print(f"   Para X (Unidades) = {valor_a_predecir_extrapolar} -> Y (Gastos generales) estimado = {pred_ext:.2f}")

print("\nComentarios:")
print("La interpolación proporciona predicciones para valores de X dentro del rango de los datos observados, lo que generalmente es más fiable.")
print("La extrapolación, al predecir valores de X fuera del rango observado, es menos fiable y debe interpretarse con precaución, ya que la relación lineal podría no mantenerse fuera de ese rango.")
# Out:
# Resultados esperados (Predicciones):
# Interpolación:
#    Para X (Unidades) = 45 -> Y (Gastos generales) estimado = 211.67
#    Para X (Unidades) = 50 -> Y (Gastos generales) estimado = 244.13
#
# Extrapolación:
#    Para X (Unidades) = 60 -> Y (Gastos generales) estimado = 309.05
#
# Comentarios:
# La interpolación proporciona predicciones para valores de X dentro del rango de los datos observados, lo que generalmente es más fiable.
# La extrapolación, al predecir valores de X fuera del rango observado, es menos fiable y debe interpretarse con precaución, ya que la relación lineal podría no mantenerse fuera de ese rango.

# %% [markdown]
# 12. Realice una tabla ANOVA e interprete el resultado.

# %%
# test de ANOVA (Analysis of Variance)
# H0: beta_1 = 0   (No hay correlación)
# H1: beta_1 ≠ 0   (Sí hay correlación)

import statsmodels.api as sm
from statsmodels.formula.api import ols
# Y ~ X
modelo_lineal = ols(
    "Q('Gatos generales') ~ Unidades",
    data = df).fit()
tabla_anova = sm.stats.anova_lm(modelo_lineal)
tabla_anova
# Out:
#            df        sum_sq       mean_sq           F        PR(>F)
# Unidades  1.0  24778.042517  24778.042517  236.669535  3.167080e-07
# Residual  8.0    837.557483    104.694685         NaN           NaN

# %% [markdown]
# Sí hay correlación porque el valor-p de $3.167080$ es menor a un nivel de significancia $\alpha=0.05$.
# I
# En los residuales del anova se puede ver la variabilidad explicada porla recta de regresión es mucho mayor que la variabilidad que queda sin explicar

# %% [markdown]
# ### Problema 4
# Las ventas de línea blanca varían según el estado del mercado de casas nuevas: cuando las ventas de casas nuevas son buenas, también lo son las de lavaplatos, lavadoras de ropa, secadoras y refrigeradores.
# Una asociación de comercio compiló los siguientes datos históricos (en miles de unidades) de las ventas de línea blanca y la construcción de casas.
#
# | Construcción de casas (miles) | Ventas de línea blanca (miles) |
# |-------------------------------|--------------------------------|
# | 2.0                           | 5.0                            |
# | 2.5                           | 5.5                            |
# | 3.2                           | 6.0                            |
# | 3.6                           | 7.0                            |
# | 3.7                           | 7.2                            |
# | 4.0                           | 7.7                            |
# | 4.2                           | 8.4                            |
# | 4.6                           | 9.0                            |
# | 4.8                           | 9.7                            |
# | 5.0                           | 10.0                           |
#
# 1.   Establesca una variable dependiente ($Y$) y una variable independiente ($X$).
# 2.   Realice un diagrama de dispersión para estos datos.
# 3. ¿Los datos soportan la suposición de linealidad?
# 4. Calcule el coeficiente de correlación e interprete el resultado.
# 5. Calcule el coeficiente de determinación e interprete el resultado.
# 6. Obtenga la recta de regresión ajustada y grafíquelo sobre el gráfico de dispersión.
# 7. Obtenga un intervalo de confianza del 95% para la pendiente de la recta de regresión ajustada ($b_1$)
# 8. Calcule los residuales y trace un nuevo gráfico de dispersión. Comente, ¿Parece que se verifican los supuestos?
# 9. Realice la prueba de Shapiro para los residuales y comente el resultado.
# 10. Realice la prueba de Brausch-Pagan para los residuales y comente el resultado.
# 11. Utiliza la recta de regresión para interpolar dos valores y extrapolar uno. Comenta estos resultados.
# 12. Realice una tabla ANOVA e interprete el resultado.

# %%
import pandas as pd

df = pd.DataFrame({
    "construccion de casas": [2.0, 2.5, 3.2, 3.6, 3.7, 4.0, 4.2, 4.6, 4.8, 5.0],
    "ventas de linea blanca": [5.0, 5.5, 6.0, 7.0, 7.2, 7.7, 8.4, 9.0, 9.7, 10.0]
})

df
# Out:
#    construccion de casas  ventas de linea blanca
# 0                    2.0                     5.0
# 1                    2.5                     5.5
# 2                    3.2                     6.0
# 3                    3.6                     7.0
# 4                    3.7                     7.2
# 5                    4.0                     7.7
# 6                    4.2                     8.4
# 7                    4.6                     9.0
# 8                    4.8                     9.7
# 9                    5.0                    10.0

# %% [markdown]
# 1. Establesca una variable dependiente ( Y ) y una variable independiente ( X ).

# %%
# Y: ventas de linea blanca
# X: construccion de casas

X = df["construccion de casas"]
Y = df["ventas de linea blanca"]

# %% [markdown]
# 2. Realice un diagrama de dispersión para estos datos.

# %%
# Importamos la librería matplotlib.pyplot y le damos el pseudónimo plt
import matplotlib.pyplot as plt

# Configuración general del gráfico
plt.figure(
    figsize=(6, 4),   # tamaño de la figura (ancho, alto) en pulgadas
    dpi=120           # resolución del gráfico
)

# Gráfico de dispersión
plt.scatter(
    X, Y,
    marker="o",       # forma: googlear "matplotlib.markers"
    color='yellow',     # color de los puntos
    edgecolor='blue',    # borde de los puntos
    alpha=0.8,            # transparencia: 0 es invisible y 1 es color sólido
    s=50,                 # tamaño de los puntos
)

# Etiquetas de los ejes
# eje x
plt.xlabel(
    'ventas de linea blanca', # etiqueta del eje x
    fontsize=12  # tamaño de fuente
)

plt.ylabel(
    'construccion de casas', # etiqueta del eje y
    fontsize=12 # tamaño de fuente
)

# Fuente de los ticks
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

# Márgenes
plt.gca().spines['right'].set_visible(False) # derecha
plt.gca().spines['top'].set_visible(False)   # superior

# Cuadrícula (opcional, pero didáctica)
plt.grid(
    visible=True,
    linestyle='--',
    linewidth=0.7,
    alpha=0.5,
    color="gray"
)

# %% [markdown]
# 3. ¿Los datos soportan la suposición de linealidad?

# %% [markdown]
# si, porque a medida que aumenta el valor de las ventas, la cantidad de construcciones crece de forma progresiva y constante.

# %% [markdown]
# 4. Calcule el coeficiente de correlación e interprete el resultado.

# %%
# Importar la función pearsonr desde scipy.stats
from scipy.stats import pearsonr

# Test de Pearson
# H0: rho = 0     (No hay correlación)
# H1: rho ≠ 0     (Sí hay correlación)
# alpha = 0.05

r, valor_p = pearsonr(X, Y)

print(f"Coeficiente de correlación: {r: 0.4f}")
print(f'valor_p: {valor_p: 0.4f}')
# Out:
# Coeficiente de correlación:  0.9808
# valor_p:  0.0000

# %% [markdown]
# El coeficiente de correlacion es $r=0.908$, este valor indica que la correlacion es fuerte, dado que esta muy cerca de 1. Ademas, el que se negativa, implica que aumentar las ausencias ($X$) disminuye el salario ($Y$).

# %% [markdown]
# 5. Calcule el coeficiente de determinación e interprete el resultado.

# %%
import statsmodels.api as sm
x_constante = sm.add_constant(X)
modelo = sm.OLS(Y, x_constante).fit()
y_calculada = modelo.predict(x_constante)

# %%
# Coeficiente de determinacion
from sklearn.metrics import r2_score

r2 = r2_score(Y, y_calculada)
print(f"Coeficiente de determinacion: {r2: 0.2%}")
# Out:
# Coeficiente de determinacion:  96.19%

# %% [markdown]
# Con coeficiente de determinacion de $r^2=0.9619$ indica que con las ausencias estoy justificando en un 96.19% la variabilidad de gastos generales. Por lo que el modelo puede tener una buena capacidad de prediccion.

# %% [markdown]
# 6. Obtenga la recta de regresión ajustada y grafíquelo sobre el gráfico de dispersión.

# %%
import statsmodels.api as sm

x_constante = sm.add_constant(X)
modelo = sm.OLS(Y, x_constante).fit()
y_calculada = modelo.predict(x_constante)

modelo.params
# Out:
# const                    1.016760
# construccion de casas    1.737564
# dtype: float64

# %% [markdown]
# La ecuacion de la recta es:
#
# $$
# \hat{y}=1.016760+1.737564X
# $$

# %%
# Importamos la librería matplotlib.pyplot y le damos el pseudónimo plt
import matplotlib.pyplot as plt

# Configuración general del gráfico
plt.figure(
    figsize=(6, 4),   # tamaño de la figura (ancho, alto) en pulgadas
    dpi=120           # resolución del gráfico
)

# Gráfico de dispersión
plt.scatter(
    X, Y,
    marker="o",       # forma: googlear "matplotlib.markers"
    color='yellow',     # color de los puntos
    edgecolor='blue',    # borde de los puntos
    alpha=0.8,            # transparencia: 0 es invisible y 1 es color sólido
    s=50,                 # tamaño de los puntos
)

# Gráfico de línea
plt.plot(
    X, y_calculada,
    color='black',   # color de la línea
    linewidth=1.0,        # grosor de la línea
    linestyle='--',        # estilo de línea
    label='Recta de regresión'
)

# Etiquetas de los ejes
# eje x
plt.xlabel(
    'ventas de linea blanca', # etiqueta del eje x
    fontsize=12  # tamaño de fuente
)

plt.ylabel(
    'construccion de casas', # etiqueta del eje y
    fontsize=12 # tamaño de fuente
)

# Fuente de los ticks
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

# Márgenes
plt.gca().spines['right'].set_visible(False) # derecha
plt.gca().spines['top'].set_visible(False)   # superior

# Cuadrícula (opcional, pero didáctica)
plt.grid(
    visible=True,
    linestyle='--',
    linewidth=0.7,
    alpha=0.5,
    color="gray"
)

# %% [markdown]
# 7. Obtenga un intervalo de confianza del 95% para la pendiente de la recta de regresión ajustada ( b1 )

# %% [markdown]
# La ecuacion de la recta es:
#
# $$
# \hat{y}=by+b1X
# $$

# %%
#intervalos de confianza
modelo.conf_int(alpha=0.05)
# Out:
#                               0         1
# const                 -0.074848  2.108368
# construccion de casas  1.455693  2.019435

# %% [markdown]
# El verdadero $b_0$ está entre $-0.074848$ y $2.108368$ con una confianza del 95%. Esto indica que las unidades ($X=0$) tiene una categoría de datos generales
# ($Y$) que está entre estos dos valores.
# EL verdadero valor de $b 1$ está entre $ 0.350635% y $-0.
# 172989$ con un 95% de confianza. Dado que dentre de este intervalo no está el valor de cero, entonces la relación es significativa. También indica que por cada falta se pierde entre 2.019435 y 1.455693 en la categoría de datos generales.

# %% [markdown]
# 8. Calcule los residuales y trace un nuevo gráfico de dispersión. Comente, ¿Parece que se verifican los supuestos?

# %%
residuales = modelo.resid

# %%
# Importamos la librería matplotlib.pyplot y le damos el pseudónimo plt
import matplotlib.pyplot as plt
import statsmodels.api as sm # Ensure sm is imported

# Re-fit the model with the current X and Y (from Problem 5)
x_constante = sm.add_constant(X)
modelo = sm.OLS(Y, x_constante).fit()
y_calculada = modelo.predict(x_constante)

residuales = modelo.resid

# Configuración general del gráfico
plt.figure(
    figsize=(6, 4),   # tamaño de la figura (ancho, alto) en pulgadas
    dpi=120           # resolución del gráfico
)


# Gráfico de dispersión
plt.scatter(
    X, residuales,
    marker="o",       # forma: googlear "matplotlib.markers"
    color='blue',     # color de los puntos
    edgecolor='black',    # borde de los puntos
    alpha=0.8,            # transparencia: 0 es invisible y 1 es color sólido
    s=50                  # tamaño de los puntos
)

 #Gráfico de línea
plt.plot(
    X,y_calculada * 0,
    color='black',   # color de la línea
    linewidth=1.0,        # grosor de la línea
    linestyle='--',        # estilo de línea
    label='Recta de regresión'
)

# Etiquetas de los ejes
# eje x
plt.xlabel(
    'número_interrupciones', # etiqueta del eje x (updated for Problem 5)
    fontsize=12  # tamaño de fuente
)

plt.ylabel(
    'calificación_del_trabajador', # etiqueta del eje y (residuals)
    fontsize=12 # tamaño de fuente
)

# Fuente de los ticks
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

# Márgenes
plt.gca().spines['right'].set_visible(False) # derecha
plt.gca().spines['top'].set_visible(False)   # superior

# Cuadrícula (opcional, pero didáctica)
plt.grid(
    visible=True,
    linestyle='--',
    linewidth=0.7,
    alpha=0.5,
    color="gray"
)

# %% [markdown]
# * Linealidad: Sí, porque los puntos se distriuyen claramente al rededor de una recta con tendencia creciente.
# * Normalidad: Sí cumple con la normalidad, porque los puntos se ubican de forma simetrica respecto a la recta ajustada.
# * Homoscedasticidad: Sí cumple con la homoscedasticidad, porque la dispersion vertical de los puntos se mantiene constante a lo largo de todo rango de la variable independiente.
# * Independencia: Sí cılmple, porque cada observacion corresponde a periodos o registros distintos.
#
# > Agregar bloque entrecomillado

# %% [markdown]
# 9. Realice la prueba de Shapiro para los residuales y comente el resultado.

# %%
from scipy.stats import shapiro
import matplotlib.pyplot as plt
import seaborn as sns

# n < 30, Shapiro-Wilk es el mas confiable
# n >= 30, Histograma o Q-Q plot

#test de shapiro-Wilk
# 1
#Ho:Hay normalidad   0.4172971767713699
# 0.05 (Assuming this was intended as alpha value or a note)
#Hi:No hay normalidad
# 0

# Prueba de Shapiro-Wilk
stat, valor_p_sh = shapiro(residuales)
print(f"valor-p (Shapiro) = {valor_p_sh}")

# Visualización: Q-Q plot
sm.qqplot(residuales, line='s')
plt.title("Q-Q plot de residuos")
plt.show()

# Histograma
sns.histplot(residuales, kde=True)
plt.title("Histograma de residuos")
plt.show()
# Out:
# valor-p (Shapiro) = 0.8463507249054649

# %% [markdown]
# 10. Realice la prueba de Brausch-Pagan para los residuales y comente el resultado.

# %%
# Test de Breusch-Pagan
# H0: No hay heterocedasticidad (dispersión es igual en toda la recta)
# H1: Hay Heterocedasticidad (dispersión distinta a lo largo de la recta)
# alpha = 0.05

from statsmodels.stats.api import het_breuschpagan
import statsmodels.api as sm
x_constante = sm.add_constant(X)
_, valor_p_bp, _, _ = het_breuschpagan(residuales, x_constante)
print(f'valor-p de Breusch-Pagan: {valor_p_bp: 0.4f}\n')
# Out:
# valor-p de Breusch-Pagan:  0.1581

# %% [markdown]
# 11. Utiliza la recta de regresión para interpolar dos valores y extrapolar uno. Comenta estos resultados.

# %%
# minimo ausencias: 11
# maximo ausencias: 40

# interpolar, valores de x entre 11 y 40

# interpolar 1
y_25 = modelo.predict([1, 25])
y_32 = modelo.predict ([1,32])

print(f"Para x = 25, y = {y_25[0]: 0.4f}")
print(f"Para x = 32, y = {y_32[0]: 0.4f}")
# Out:
# Para x = 25, y =  44.4559
# Para x = 32, y =  56.6188

# %%
df["salario_predicho"] = y_calculada.round()
df
# Out:
#    construccion de casas  ventas de linea blanca  salario_predicho
# 0                    2.0                     5.0               4.0
# 1                    2.5                     5.5               5.0
# 2                    3.2                     6.0               7.0
# 3                    3.6                     7.0               7.0
# 4                    3.7                     7.2               7.0
# 5                    4.0                     7.7               8.0
# 6                    4.2                     8.4               8.0
# 7                    4.6                     9.0               9.0
# 8                    4.8                     9.7               9.0
# 9                    5.0                    10.0              10.0

# %% [markdown]
# 12. Realice una tabla ANOVA e interprete el resultado.

# %%
# test de ANOVA (Analysis of Variance)
# H0: beta_1 = 0   (No hay correlación)
# H1: beta_1 ≠ 0   (Sí hay correlación)

import statsmodels.api as sm
from statsmodels.formula.api import ols
# Y ~ X
modelo_lineal = ols(
    '''Q('ventas de linea blanca') ~ Q('construccion de casas')''',
    data = df).fit()
tabla_anova = sm.stats.anova_lm(modelo_lineal)
tabla_anova
# Out:
#                              df     sum_sq    mean_sq           F  \
# Q('construccion de casas')  1.0  25.976581  25.976581  202.069951
# Residual                    8.0   1.028419   0.128552         NaN
#
#                                   PR(>F)
# Q('construccion de casas')  5.841003e-07
# Residual                             NaN

# %% [markdown]
# Sí hay correlación porque el valor-p de $5.841003$ es menor a un nivel de significancia $\alpha=0.05$.
# I
# En los residuales del anova se puede ver la variabilidad explicada porla recta de regresión es mucho mayor que la variabilidad que queda sin explicar

# %% [markdown]
# ### Problema 5
# William C. Andrews, consultor de comportamiento organizacional de Victory Motorcycles, ha diseñado una prueba para mostrar a los supervisores de la compañía los peligros de sobrevigilar a sus trabajadores.
# Un trabajador de la línea de ensamble tiene a su cargo una serie de tareas complicadas. Durante el desempeño del trabajador, un inspector lo interrumpe constantemente para ayudarlo a terminar las tareas.
# El trabajador, después de terminar su trabajo, recibe una prueba psicológica diseñada para medir la hostilidad del trabajador hacia la autoridad
# (una alta puntuación implica una hostilidad baja). A ocho distintos trabajadores se les asignaron las tareas y luego se les interrumpió para darles instrucciones útiles un número variable de veces (línea X).
# Sus calificaciones en la prueba de hostilidad se dan en el renglón Y.
#
# | número interrupciones al trabajador |  5  | 10  | 10  | 15  | 15  | 20  | 20  | 25  |
# |-----------------------------------------|----|----|----|----|----|----|----|----|
# | calificación del trabajador en la prueba de hostilidad | 58  | 41  | 45  | 27  | 26  | 12  | 16  |  3  |
#
# 1.   Establesca una variable dependiente ($Y$) y una variable independiente ($X$).
# 2.   Realice un diagrama de dispersión para estos datos.
# 3. ¿Los datos soportan la suposición de linealidad?
# 4. Calcule el coeficiente de correlación e interprete el resultado.
# 5. Calcule el coeficiente de determinación e interprete el resultado.
# 6. Obtenga la recta de regresión ajustada y grafíquelo sobre el gráfico de dispersión.
# 7. Obtenga un intervalo de confianza del 95% para la pendiente de la recta de regresión ajustada ($b_1$)
# 8. Calcule los residuales y trace un nuevo gráfico de dispersión. Comente, ¿Parece que se verifican los supuestos?
# 9. Realice la prueba de Shapiro para los residuales y comente el resultado.
# 10. Realice la prueba de Brausch-Pagan para los residuales y comente el resultado.
# 11. Utiliza la recta de regresión para interpolar dos valores y extrapolar uno. Comenta estos resultados.
# 12. Realice una tabla ANOVA e interprete el resultado.

# %%
import pandas as pd

df = pd.DataFrame({
    "número_interrupciones": [5, 10, 10, 15,	15,	20,	20,	25],
    "calificación_del_trabajador": [58,	41,	45,	27,	26,	12,	16,	3]
})

df
# Out:
#    número_interrupciones  calificación_del_trabajador
# 0                      5                           58
# 1                     10                           41
# 2                     10                           45
# 3                     15                           27
# 4                     15                           26
# 5                     20                           12
# 6                     20                           16
# 7                     25                            3

# %% [markdown]
# 1. Establesca una variable dependiente ( Y ) y una variable independiente ( X ).
#
# Y : Gastos generales, porque el problema indica que se estiman con base en el nivel de producción.
#
# X : Unidades, porque son la variable en la que se basa la estimación de los gastos generales.

# %%
X = df["número_interrupciones"]
Y = df["calificación_del_trabajador"]

# %% [markdown]
# 2. Realice un diagrama de dispersión para estos datos.

# %%
# Importamos la librería matplotlib.pyplot y le damos el pseudónimo plt
import matplotlib.pyplot as plt

# Configuración general del gráfico
plt.figure(
    figsize=(6, 4),   # tamaño de la figura (ancho, alto) en pulgadas
    dpi=120           # resolución del gráfico
)

# Gráfico de dispersión
plt.scatter(
    X, Y,
    marker="o",       # forma: googlear "matplotlib.markers"
    color='yellow',     # color de los puntos
    edgecolor='blue',    # borde de los puntos
    alpha=0.8,            # transparencia: 0 es invisible y 1 es color sólido
    s=50,                 # tamaño de los puntos
)

# Etiquetas de los ejes
# eje x
plt.xlabel(
    'calificación_del_trabajador', # etiqueta del eje x
    fontsize=12  # tamaño de fuente
)

plt.ylabel(
    'número_interrupciones', # etiqueta del eje y
    fontsize=12 # tamaño de fuente
)

# Fuente de los ticks
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

# Márgenes
plt.gca().spines['right'].set_visible(False) # derecha
plt.gca().spines['top'].set_visible(False)   # superior

# Cuadrícula (opcional, pero didáctica)
plt.grid(
    visible=True,
    linestyle='--',
    linewidth=0.7,
    alpha=0.5,
    color="gray"
)

# %% [markdown]
# 3. ¿Los datos soportan la suposición de linealidad?

# %% [markdown]
# Si, por que medida que aumenta la calificación del trabajador, disminuye de forma constante y ordenada el número de interrupciones.

# %% [markdown]
# 4. Calcule el coeficiente de correlación e interprete el resultado

# %%
# Importar la función pearsonr desde scipy.stats
from scipy.stats import pearsonr

# Test de Pearson
# H0: rho = 0     (No hay correlación)
# H1: rho ≠ 0     (Sí hay correlación)
# alpha = 0.05

r, valor_p = pearsonr(X, Y)

print(f"Coeficiente de correlación: {r: 0.4f}")
print(f'valor_p: {valor_p: 0.4f}')
# Out:
# Coeficiente de correlación: -0.9928
# valor_p:  0.0000

# %% [markdown]
# El coeficiente de correlacion es $r=-0.9928$, este valor indica que la correlacion es fuerte, dado que esta muy cerca de 1. Ademas, el que se negativa, implica que aumentar las ausencias ($X$) disminuye el salario ($Y$).

# %% [markdown]
# 5. Calcule el coeficiente de determinación e interprete el resultado.

# %%
import statsmodels.api as sm
x_constante = sm.add_constant(X)
modelo = sm.OLS(Y, x_constante).fit()
y_calculada = modelo.predict(x_constante)

# Coeficiente de determinacion
from sklearn.metrics import r2_score

r2 = r2_score(Y, y_calculada)
print(f"Coeficiente de determinacion: {r2: 0.2%}")
# Out:
# Coeficiente de determinacion:  98.58%

# %% [markdown]
# Con coeficiente de determinacion de $r^2=0.9858$ indica que con las ausencias estoy justificando en un 98.58% la variabilidad de los salarios. Por lo que el modelo puede tener una buena capacidad de prediccion.

# %% [markdown]
# 6. Obtenga la recta de regresión ajustada y grafíquelo sobre el gráfico de dispersión.

# %%
import statsmodels.api as sm

x_constante = sm.add_constant(X)
modelo = sm.OLS(Y, x_constante).fit()
y_calculada = modelo.predict(x_constante)

modelo.params
# Out:
# const                    70.5
# número_interrupciones    -2.8
# dtype: float64

# %% [markdown]
# La ecuacion de la recta es:
#
# $$
# \hat{y}=70.5-2.8X
# $$

# %%
# Importamos la librería matplotlib.pyplot y le damos el pseudónimo plt
import matplotlib.pyplot as plt

# Configuración general del gráfico
plt.figure(
    figsize=(6, 4),   # tamaño de la figura (ancho, alto) en pulgadas
    dpi=120           # resolución del gráfico
)

# Gráfico de dispersión
plt.scatter(
    X, Y,
    marker="o",       # forma: googlear "matplotlib.markers"
    color='yellow',     # color de los puntos
    edgecolor='blue',    # borde de los puntos
    alpha=0.8,            # transparencia: 0 es invisible y 1 es color sólido
    s=50,                 # tamaño de los puntos
)

# Gráfico de línea
plt.plot(
    X, y_calculada,
    color='black',   # color de la línea
    linewidth=1.0,        # grosor de la línea
    linestyle='--',        # estilo de línea
    label='Recta de regresión'
)

# Etiquetas de los ejes
# eje x
plt.xlabel(
    'calificación_del_trabajador', # etiqueta del eje x
    fontsize=12  # tamaño de fuente
)

plt.ylabel(
    'número_interrupciones', # etiqueta del eje y
    fontsize=12 # tamaño de fuente
)

# Fuente de los ticks
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

# Márgenes
plt.gca().spines['right'].set_visible(False) # derecha
plt.gca().spines['top'].set_visible(False)   # superior

# Cuadrícula (opcional, pero didáctica)
plt.grid(
    visible=True,
    linestyle='--',
    linewidth=0.7,
    alpha=0.5,
    color="gray"
)

# %% [markdown]
# 7. Obtenga un intervalo de confianza del 95% para la pendiente de la recta de regresión ajustada ( b1 )

# %% [markdown]
# La ecuacion de la recta es:
#
# $$
# \hat{y}=by+b1X
# $$

# %%
#intervalos de confianza
modelo.conf_int(alpha=0.05)
# Out:
#                                              0          1
# const                                65.051384  75.948616
# número interrupciones al trabajador  -3.136296  -2.463704

# %% [markdown]
# El verdadero $b_0$ está entre $65.051384$ y $75.948616$ con una confianza del 95%. Esto indica que una persona sin ausencias ($X=0$) tiene una categoría de salario
# ($Y$) que está entre estos dos valores.
# EL verdadero valor de $b 1$ está entre $ 0.350635% y $-0.
# 172989$ con un 95% de confianza. Dado que dentre de este intervalo no está el valor de cero, entonces la relación es significativa. También indica que por cada falta se pierde entre -2.463704 y -3.136296 en la categoría de salario

# %% [markdown]
# 8. Calcule los residuales y trace un nuevo gráfico de dispersión. Comente, ¿Parece que se verifican los supuestos?

# %%
# Importamos la librería matplotlib.pyplot y le damos el pseudónimo plt
import matplotlib.pyplot as plt

residuales = modelo.resid

# Configuración general del gráfico
plt.figure(
    figsize=(6, 4),   # tamaño de la figura (ancho, alto) en pulgadas
    dpi=120           # resolución del gráfico
)


# Gráfico de dispersión
plt.scatter(
    X, residuales,
    marker="o",       # forma: googlear "matplotlib.markers"
    color='blue',     # color de los puntos
    edgecolor='black',    # borde de los puntos
    alpha=0.8,            # transparencia: 0 es invisible y 1 es color sólido
    s=50,                 # tamaño de los puntos
)

 #Gráfico de línea
plt.plot(
    X,y_calculada * 0,
    color='black',   # color de la línea
    linewidth=1.0,        # grosor de la línea
    linestyle='--',        # estilo de línea
    label='Recta de regresión'
)

# Etiquetas de los ejes
# eje x
plt.xlabel(
    'calificación_del_trabajador', # etiqueta del eje x
    fontsize=12  # tamaño de fuente
)

plt.ylabel(
    'número_interrupciones', # etiqueta del eje y
    fontsize=12 # tamaño de fuente
)

# Fuente de los ticks
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

# Márgenes
plt.gca().spines['right'].set_visible(False) # derecha
plt.gca().spines['top'].set_visible(False)   # superior

# Cuadrícula (opcional, pero didáctica)
plt.grid(
    visible=True,
    linestyle='--',
    linewidth=0.7,
    alpha=0.5,
    color="gray"
)

# %% [markdown]
# Par los supuestos:
#
# * Linealidad: Sí, porque los puntos siguen una tendencia rectilínea descendente clara y se ajustan de forma ordenada a la recta de regresión, sin mostrar curvas ni patrones no lineales.
# * Normalidad: Sí cumple con la normalidad, porque los residuos se dispersan de forma simétrica alrededor de la recta ajustada y no presentan desviaciones extremas ni asimetrías marcadas.
# * Homoscedasticidad: Sí cumple con la homoscedasticidad, porque la dispersión de los puntos respecto a la recta se mantiene constante en todo el rango de la variable independiente; no se observa que la variabilidad aumente ni disminuya al cambiar el valor de la calificación del trabajador.
# * Independencia: Sí cılmple, porque no existe relación ni influencia entre una observación y otra; los datos son mediciones independientes, sin seguir ciclos, tendencias o patrones que hagan que un valor dependa de los anteriores.

# %% [markdown]
# 9. Realice la prueba de Shapiro para los residuales y comente el resultado.

# %%
from scipy.stats import shapiro
import matplotlib.pyplot as plt
import seaborn as sns

# Prueba de Shapiro-Wilk
stat, valor_p_sh = shapiro(residuales)
print(f"valor-p (Shapiro) = {valor_p_sh: 0.4f}")

# Visualización: Q-Q plot
sm.qqplot(residuales, line='s')
plt.title("Q-Q plot de residuos")
plt.show()

# Histograma
sns.histplot(residuales, kde=True)
plt.title("Histograma de residuos")
plt.show()
# Out:
# valor-p (Shapiro) =  0.0548

# %% [markdown]
# 10. Realice la prueba de Brausch-Pagan para los residuales y comente el resultado.

# %%
from statsmodels.stats.api import het_breuschpagan
import statsmodels.api as sm

x_constante = sm.add_constant(X)
_, valor_p_bp, _, _ = het_breuschpagan(residuales, x_constante)
print(f'valor-p de Breusch-Pagan: {valor_p_bp: 0.4f}\n')
# Out:
# valor-p de Breusch-Pagan:  0.2482

# %% [markdown]
# 11. Utiliza la recta de regresión para interpolar dos valores y extrapolar uno. Comenta estos resultados.

# %%
# Minimo de Unidades: 5
# Maximo de Unidades: 25

# Interpolar: Valores de X entre 5 y 25
y_45 = modelo.predict([1, 25])
y_50 = modelo.predict ([1, 32])

print(f"Para X = 45 Unidades, Y (Gastos generales) = {y_45[0]: 0.4f}")
print(f"Para X = 50 Unidades, Y (Gastos generales) = {y_50[0]: 0.4f}")
# Out:
# Para X = 45 Unidades, Y (Gastos generales) =  0.5000
# Para X = 50 Unidades, Y (Gastos generales) = -19.1000

# %% [markdown]
# 12. Realice una tabla ANOVA e interprete el resultado.

# %%
# test de ANOVA (Analysis of Variance)
# H0: beta_1 = 0   (No hay correlación)
# H1: beta_1 ≠ 0   (Sí hay correlación)

import statsmodels.api as sm
from statsmodels.formula.api import ols
# Y ~ X
modelo_lineal = ols(
    "Q('calificación_del_trabajador') ~ Q('número_interrupciones')",
    data = df).fit()
tabla_anova = sm.stats.anova_lm(modelo_lineal)
tabla_anova
# Out:
#                              df  sum_sq      mean_sq           F        PR(>F)
# Q('número_interrupciones')  1.0  2352.0  2352.000000  415.058824  9.090964e-07
# Residual                    6.0    34.0     5.666667         NaN           NaN

# %% [markdown]
# Sí hay correlación porque el valor-p de $9.090964$ es menor a un nivel de significancia $\alpha=0.05$.
# I
# En los residuales del anova se puede ver la variabilidad explicada porla recta de regresión es mucho mayor que la variabilidad que queda sin explicar
